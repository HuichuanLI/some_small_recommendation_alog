# %%
import pandas as pd
import numpy as np
import time
import sqlite3
data_home = './'

# %%
#读取数据集
triplet_dataset = pd.read_csv(filepath_or_buffer=data_home+'train_triplets.txt', 
                              sep='\t', header=None, 
                              names=['user','song','play_count'])

# %%
#数据集大小
triplet_dataset.shape
# Out:
# (48373586, 3)

# %%
#数据集信息
triplet_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48373586 entries, 0 to 48373585
# Data columns (total 3 columns):
# user          object
# song          object
# play_count    int64
# dtypes: int64(1), object(2)
# memory usage: 1.1+ GB

# %%
#查看原始数据
triplet_dataset.head(n=10)
# Out:
#                                        user                song  play_count
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995           1
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAPDEY12A81C210A9           1
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B           2
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBFNSP12AF72A0E22           1
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBFOVM12A58A7D494           1
# 5  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBNZDC12A6D4FC103           1
# 6  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBSUJE12A6D4F8CF5           2
# 7  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBVFZR12A6D4F8AE3           1
# 8  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXALG12A8C13C108           1
# 9  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0           1

# %%
#对每一个用户，分别统计其播放量
output_dict = {}
with open(data_home+'train_triplets.txt') as f:
    for line_number, line in enumerate(f):
        #找到当前的用户
        user = line.split('\t')[0]
        #得到其播放量数据
        play_count = int(line.split('\t')[2])
        #如果字典中已经有该用户信息，在其基础上增加当前的播放量
        if user in output_dict:
            play_count +=output_dict[user]
            output_dict.update({user:play_count})
        output_dict.update({user:play_count})
# 统计 用户-总播放量
output_list = [{'user':k,'play_count':v} for k,v in output_dict.items()]
#转换成DF格式
play_count_df = pd.DataFrame(output_list)
#排序
play_count_df = play_count_df.sort_values(by = 'play_count', ascending = False)
#输出为表格，保存下来
play_count_df.to_csv(path_or_buf='user_playcount_df.csv', index = False)

# %%
#对每首歌，统计其播放量，统计方法跟上述类似
output_dict = {}
with open(data_home+'train_triplets.txt') as f:
    for line_number, line in enumerate(f):
        #找到当前歌曲
        song = line.split('\t')[1]
        #找到当前播放次数
        play_count = int(line.split('\t')[2])
        #统计每首歌曲被播放的总次数
        if song in output_dict:
            play_count +=output_dict[song]
            output_dict.update({song:play_count})
        output_dict.update({song:play_count})
output_list = [{'song':k,'play_count':v} for k,v in output_dict.items()]
#转换成df格式
song_count_df = pd.DataFrame(output_list)
song_count_df = song_count_df.sort_values(by = 'play_count', ascending = False)
#输出保存
song_count_df.to_csv(path_or_buf='song_playcount_df.csv', index = False)

# %%
#查看目前用户播放排行
play_count_df = pd.read_csv(filepath_or_buffer='user_playcount_df.csv')
play_count_df.head(n =10)
# Out:
#    play_count                                      user
# 0       13132  093cb74eb3c517c5179ae24caf0ebec51b24d2a2
# 1        9884  119b7c88d58d0c6eb051365c103da5caf817bea6
# 2        8210  3fa44653315697f42410a30cb766a4eb102080bb
# 3        7015  a2679496cd0af9779a92a13ff7c6af5c81ea8c7b
# 4        6494  d7d2d888ae04d16e994d6964214a1de81392ee04
# 5        6472  4ae01afa8f2430ea0704d502bc7b57fb52164882
# 6        6150  b7c24f770be6b802805ac0e2106624a517643c17
# 7        5656  113255a012b2affeab62607563d03fbdf31b08e7
# 8        5620  6d625c6557df84b60d90426c0116138b617b9449
# 9        5602  99ac3d883681e21ea68071019dba828ce76fe94d

# %%
#查看目前歌曲播放排行
song_count_df = pd.read_csv(filepath_or_buffer='song_playcount_df.csv')
song_count_df.head(10)
# Out:
#    play_count                song
# 0      726885  SOBONKR12A58A7A7E0
# 1      648239  SOAUWYT12A81C206F1
# 2      527893  SOSXLTC12AF72A7F54
# 3      425463  SOFRQTD12A81C233C0
# 4      389880  SOEGIYH12A6D4FC0E3
# 5      356533  SOAXGDH12A8C13F8A1
# 6      292642  SONYKOW12AB01849C9
# 7      274627  SOPUCYA12A8C13A694
# 8      268353  SOUFTBI12AB0183F65
# 9      244730  SOVDSJC12A58A7A271

# %%
#10W名用户的播放量占总体的比例
total_play_count = sum(song_count_df.play_count)
print ((float(play_count_df.head(n=100000).play_count.sum())/total_play_count)*100)
play_count_subset = play_count_df.head(n=100000)
# Out:
# 40.8807280500655

# %%
#3W的首歌播放量占总体的比例
(float(song_count_df.head(n=30000).play_count.sum())/total_play_count)*100
song_count_subset = song_count_df.head(n=30000)

# %%
#取10W个用户，3W首歌
user_subset = list(play_count_subset.user)
song_subset = list(song_count_subset.song)

# %%
#读取原始数据集
triplet_dataset = pd.read_csv(filepath_or_buffer=data_home+'train_triplets.txt',sep='\t', 
                              header=None, names=['user','song','play_count'])
#只保留有这10W名用户的数据，其余过滤掉
triplet_dataset_sub = triplet_dataset[triplet_dataset.user.isin(user_subset) ]
del(triplet_dataset)
#只保留有这3W首歌曲的数据，其余也过滤掉
triplet_dataset_sub_song = triplet_dataset_sub[triplet_dataset_sub.song.isin(song_subset)]
del(triplet_dataset_sub)

# %%
#输出提取的数据
triplet_dataset_sub_song.to_csv(path_or_buf=data_home+'triplet_dataset_sub_song.csv', index=False)
#提取后数据大小
triplet_dataset_sub_song.shape
# Out:
# (10774558, 3)

# %%
#加入音乐详细信息，合并两个数据集
conn = sqlite3.connect(data_home+'track_metadata.db')
cur = conn.cursor()
cur.execute("SELECT name FROM sqlite_master WHERE type='table'")
cur.fetchall()
# Out:
# [('songs',)]

# %%
#根据歌曲名合并两个数据集
track_metadata_df = pd.read_sql(con=conn, sql='select * from songs')
track_metadata_df_sub = track_metadata_df[track_metadata_df.song_id.isin(song_subset)]
track_metadata_df_sub.to_csv(path_or_buf=data_home+'track_metadata_df_sub.csv', index=False)
track_metadata_df_sub.shape
# Out:
# (30447, 14)

# %%
#现有数据
triplet_dataset_sub_song = pd.read_csv(filepath_or_buffer=data_home+'triplet_dataset_sub_song.csv',encoding = "ISO-8859-1")
track_metadata_df_sub = pd.read_csv(filepath_or_buffer=data_home+'track_metadata_df_sub.csv',encoding = "ISO-8859-1")

# %%
triplet_dataset_sub_song.head()
# Out:
#                                        user                song  play_count
# 0  d6589314c0a9bcbca4fee0c93b14bc402363afea  SOADQPP12A67020C82          12
# 1  d6589314c0a9bcbca4fee0c93b14bc402363afea  SOAFTRR12AF72A8D4D           1
# 2  d6589314c0a9bcbca4fee0c93b14bc402363afea  SOANQFY12AB0183239           1
# 3  d6589314c0a9bcbca4fee0c93b14bc402363afea  SOAYATB12A6701FD50           1
# 4  d6589314c0a9bcbca4fee0c93b14bc402363afea  SOBOAFP12A8C131F36           7

# %%
track_metadata_df_sub.head()
# Out:
#              track_id                                      title  \
# 0  TRMMGCB128E079651D  Get Along (Feat: Pace Won) (Instrumental)
# 1  TRMMGTX128F92FB4D9                                      Viejo
# 2  TRMMGDP128F933E59A                      I Say A Little Prayer
# 3  TRMMHBF12903CF6E59                    At the Ball_ That's All
# 4  TRMMHKG12903CDB1B5                                 Black Gold
#
#               song_id                                            release  \
# 0  SOHNWIM12A67ADF7D9                                           Charango
# 1  SOECFIW12A8C144546                                           Caraluna
# 2  SOGWEOB12AB018A4D0  The Legendary Hi Records Albums_ Volume 3: Ful...
# 3  SOJGCRL12A8C144187         Best of Laurel & Hardy - The Lonesome Pine
# 4  SOHNFBA12AB018CD1D                                 Total Life Forever
#
#             artist_id                           artist_mbid     artist_name  \
# 0  ARU3C671187FB3F71B  067102ea-9519-4622-9077-57ca4164cfbb       Morcheeba
# 1  ARPAAPH1187FB3601B  f69d655c-ffd6-4bee-8c2a-3086b2be2fc6         Bacilos
# 2  ARNNRN31187B9AE7B7  fb7272ba-f130-4f0a-934d-6eeea4c18c9a        Al Green
# 3  AR1FEUF1187B9AF3E3  4a8ae4fd-ad6f-4912-851f-093f12ee3572  Laurel & Hardy
# 4  ARVXV1J1187FB5BF88  6a65d878-fcd0-42cf-aff9-ca1d636a8bcc           Foals
#
#     duration  artist_familiarity  artist_hotttnesss  year  track_7digitalid  \
# 0  227.47383            0.819087           0.533117  2002            185967
# 1  307.51302            0.595554           0.400705     0           6825058
# 2  133.58975            0.779490           0.599210  1978           5211723
# 3  123.71546            0.438709           0.307120     0           8645877
# 4  386.32444            0.842578           0.514523  2010           9007438
#
#    shs_perf  shs_work
# 0        -1         0
# 1        -1         0
# 2        -1     11898
# 3        -1         0
# 4        -1         0

# %%
#清洗数据
# 去掉无用的信息
del(track_metadata_df_sub['track_id'])
del(track_metadata_df_sub['artist_mbid'])
# 去掉重复的
track_metadata_df_sub = track_metadata_df_sub.drop_duplicates(['song_id'])
# 将这份音乐信息数据和我们之前的播放数据整合到一起
triplet_dataset_sub_song_merged = pd.merge(triplet_dataset_sub_song, track_metadata_df_sub, how='left', left_on='song', right_on='song_id')
# 可以自己改变列名
triplet_dataset_sub_song_merged.rename(columns={'play_count':'listen_count'},inplace=True)

# %%
# 去掉不需要的指标
del(triplet_dataset_sub_song_merged['song_id'])
del(triplet_dataset_sub_song_merged['artist_id'])
del(triplet_dataset_sub_song_merged['duration'])
del(triplet_dataset_sub_song_merged['artist_familiarity'])
del(triplet_dataset_sub_song_merged['artist_hotttnesss'])
del(triplet_dataset_sub_song_merged['track_7digitalid'])
del(triplet_dataset_sub_song_merged['shs_perf'])
del(triplet_dataset_sub_song_merged['shs_work'])

# %%
#清洗后的数据
triplet_dataset_sub_song_merged.head(n=10)
# Out:
#                                        user                song  listen_count  \
# 0  d6589314c0a9bcbca4fee0c93b14bc402363afea  SOADQPP12A67020C82            12
# 1  d6589314c0a9bcbca4fee0c93b14bc402363afea  SOAFTRR12AF72A8D4D             1
# 2  d6589314c0a9bcbca4fee0c93b14bc402363afea  SOANQFY12AB0183239             1
# 3  d6589314c0a9bcbca4fee0c93b14bc402363afea  SOAYATB12A6701FD50             1
# 4  d6589314c0a9bcbca4fee0c93b14bc402363afea  SOBOAFP12A8C131F36             7
# 5  d6589314c0a9bcbca4fee0c93b14bc402363afea  SOBONKR12A58A7A7E0            26
# 6  d6589314c0a9bcbca4fee0c93b14bc402363afea  SOBZZDU12A6310D8A3             7
# 7  d6589314c0a9bcbca4fee0c93b14bc402363afea  SOCAHRT12A8C13A1A4             5
# 8  d6589314c0a9bcbca4fee0c93b14bc402363afea  SODASIJ12A6D4F5D89             1
# 9  d6589314c0a9bcbca4fee0c93b14bc402363afea  SODEAWL12AB0187032             8
#
#                                                title  \
# 0                                   You And Me Jesus
# 1                      Harder Better Faster Stronger
# 2                                           Uprising
# 3                             Breakfast At Tiffany's
# 4                              Lucky (Album Version)
# 5                                     You're The One
# 6                              Don't Dream It's Over
# 7                                             S.O.S.
# 8                                  The Invisible Man
# 9  American Idiot [feat. Green Day & The Cast Of ...
#
#                                              release  \
# 0                               Tribute To Jake Hess
# 1                                          Discovery
# 2                                           Uprising
# 3                                               Home
# 4              We Sing.  We Dance.  We Steal Things.
# 5                                 If There Was A Way
# 6  Recurring Dream_ Best Of Crowded House (Domest...
# 7                                                SOS
# 8                                  The Invisible Man
# 9  The Original Broadway Cast Recording 'American...
#
#                    artist_name  year
# 0                    Jake Hess  2004
# 1                    Daft Punk  2007
# 2                         Muse     0
# 3          Deep Blue Something  1993
# 4  Jason Mraz & Colbie Caillat     0
# 5                Dwight Yoakam  1990
# 6                Crowded House  1986
# 7               Jonas Brothers  2007
# 8                Michael Cretu  1985
# 9                    Green Day     0

# %%
triplet_dataset_sub_song_merged = pd.read_csv(filepath_or_buffer='triplet_dataset_sub_song_merged.csv')

# %%
from pylab import mpl
mpl.rcParams['font.sans-serif'] = ['SimHei']

# %%
#展示最流行歌曲
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
from pylab import mpl
mpl.rcParams['font.sans-serif'] = ['SimHei']
#按歌曲名字来统计其播放量的总数
popular_songs = triplet_dataset_sub_song_merged[['title','listen_count']].groupby('title').sum().reset_index()
#对结果进行排序
popular_songs_top_20 = popular_songs.sort_values('listen_count', ascending=False).head(n=20)

#转换成list格式方便画图
objects = (list(popular_songs_top_20['title']))
#设置位置
y_pos = np.arange(len(objects))
#对应结果值
performance = list(popular_songs_top_20['listen_count'])
#绘图
plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects, rotation='vertical')
plt.ylabel('播放量')
plt.title('最受欢迎歌曲')
 
plt.show()

# %%
#按专辑名字来统计播放总量
popular_release = triplet_dataset_sub_song_merged[['release','listen_count']].groupby('release').sum().reset_index()
#排序
popular_release_top_20 = popular_release.sort_values('listen_count', ascending=False).head(n=20)

objects = (list(popular_release_top_20['release']))
y_pos = np.arange(len(objects))
performance = list(popular_release_top_20['listen_count'])
#绘图 
plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects, rotation='vertical')
plt.ylabel('播放量')
plt.title('最受欢迎专辑')
 
plt.show()

# %%
#按歌手来统计其播放总量
popular_artist = triplet_dataset_sub_song_merged[['artist_name','listen_count']].groupby('artist_name').sum().reset_index()
#排序
popular_artist_top_20 = popular_artist.sort_values('listen_count', ascending=False).head(n=20)

objects = (list(popular_artist_top_20['artist_name']))
y_pos = np.arange(len(objects))
performance = list(popular_artist_top_20['listen_count'])
#绘图 
plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects, rotation='vertical')
plt.ylabel('播放量')
plt.title('最受欢迎歌手')
 
plt.show()

# %% [markdown]
# 解决冷启动问题

# %%
import Recommenders as Recommenders
from sklearn.model_selection import train_test_split

# %%
triplet_dataset_sub_song_merged_set = triplet_dataset_sub_song_merged
train_data, test_data = train_test_split(triplet_dataset_sub_song_merged_set, test_size = 0.40, random_state=0)

# %%
train_data.head()
# Out:
#                                               user                song  \
# 1901799   28866ea8a809d5d46273cd0989c5515c660ef8c7  SOEYVHS12AB0181D31
# 4815185   c9608a24a2a40e0ec38993a70532e7bb56eff22b  SOKIYKQ12A8AE464FC
# 10513026  24f0b09c133a6a0fe42f097734215dceb468d449  SOETFVO12AB018DFF3
# 2659073   4da3c59a0af73245cea000fd5efa30384182bfcb  SOAXJOU12A6D4F6685
# 5506263   b46c5ed385cad7ecea8af6214f440d19de6eb6c2  SOXBCAY12AB0189EE0
#
#           listen_count                                             title  \
# 1901799              1                                           Monster
# 4815185              2                               Fight For Your Life
# 10513026             1  Free Style (feat. Kevo_ Mussilini & Lyrical 187)
# 2659073              1                                   Littlest Things
# 5506263              1                           La trama y el desenlace
#
#                      release     artist_name  year
# 1901799     The Fame Monster       Lady GaGa  2009
# 4815185          Made In NYC  The Casualties  2000
# 10513026  A Bad Azz Mix Tape            Z-RO     0
# 2659073       Alright_ Still      Lily Allen  2006
# 5506263        Amar la trama   Jorge Drexler  2010

# %%
def create_popularity_recommendation(train_data, user_id, item_id):
    #根据指定的特征来统计其播放情况，可以选择歌曲名，专辑名，歌手名
    train_data_grouped = train_data.groupby([item_id]).agg({user_id: 'count'}).reset_index()
    #为了直观展示，我们用得分来表示其结果
    train_data_grouped.rename(columns = {user_id: 'score'},inplace=True)
    
    #排行榜单需要排序
    train_data_sort = train_data_grouped.sort_values(['score', item_id], ascending = [0,1])
    
    #加入一项排行等级，表示其推荐的优先级
    train_data_sort['Rank'] = train_data_sort['score'].rank(ascending=0, method='first')
        
    #返回指定个数的推荐结果
    popularity_recommendations = train_data_sort.head(10)
    return popularity_recommendations

# %%
#按歌曲名
recommendations = create_popularity_recommendation(triplet_dataset_sub_song_merged,'user','title')

# %%
recommendations
# Out:
#                                                    title  score  Rank
# 19580                                      Sehr kosmisch  18626   1.0
# 5780                      Dog Days Are Over (Radio Edit)  17635   2.0
# 27314                                     You're The One  16085   3.0
# 19542                                            Secrets  15138   4.0
# 18636                                            Revelry  14945   5.0
# 25070                                               Undo  14687   6.0
# 7530                                           Fireflies  13085   7.0
# 9640                                    Hey_ Soul Sister  12993   8.0
# 25216                                       Use Somebody  12793   9.0
# 9921   Horn Concerto No. 4 in E flat K495: II. Romanc...  12346  10.0

# %%
#按专辑名
recommendations = create_popularity_recommendation(triplet_dataset_sub_song_merged,'user','release')
recommendations
# Out:
#                                 release  score  Rank
# 4786                      Greatest Hits  74197   1.0
# 7925                          My Worlds  37006   2.0
# 7144                              Lungs  30967   3.0
# 13737                         Waking Up  27839   4.0
# 467         A Rush Of Blood To The Head  27008   5.0
# 9911             Save Me_ San Francisco  26407   6.0
# 8512                  Only By The Night  25755   7.0
# 13566                   Vampire Weekend  25603   8.0
# 11907                  The Fame Monster  25040   9.0
# 8266   Now That's What I Call Music! 75  23291  10.0

# %%
#按歌手
recommendations = create_popularity_recommendation(triplet_dataset_sub_song_merged,'user','artist_name')
recommendations
# Out:
#                  artist_name   score  Rank
# 1686                Coldplay  125818   1.0
# 7505          The Black Keys   95067   2.0
# 7795             The Killers   74316   3.0
# 3594            Jack Johnson   72891   4.0
# 4298           Kings Of Leon   69684   5.0
# 6245               Radiohead   69342   6.0
# 1908               Daft Punk   64997   7.0
# 5467                    Muse   64687   8.0
# 2850  Florence + The Machine   61106   9.0
# 5202               Metallica   46141  10.0

# %%
#方法已封装在.py文件Recommenders中，可直接调用
pop_rec = Recommenders.popularity_recommender_py()
pop_rec.create(train_data, 'user', 'title')
user_id = list(train_data.user)[8]
pop_rec.recommend(user_id)
# Out:
#                                         user_id  \
# 19580  5fd60c59d3e796b9b184768642d5fbb3750e575f
# 5780   5fd60c59d3e796b9b184768642d5fbb3750e575f
# 27314  5fd60c59d3e796b9b184768642d5fbb3750e575f
# 19542  5fd60c59d3e796b9b184768642d5fbb3750e575f
# 18636  5fd60c59d3e796b9b184768642d5fbb3750e575f
# 25070  5fd60c59d3e796b9b184768642d5fbb3750e575f
# 7530   5fd60c59d3e796b9b184768642d5fbb3750e575f
# 9640   5fd60c59d3e796b9b184768642d5fbb3750e575f
# 25216  5fd60c59d3e796b9b184768642d5fbb3750e575f
# 9921   5fd60c59d3e796b9b184768642d5fbb3750e575f
#
#                                                    title  score  Rank
# 19580                                      Sehr kosmisch  11175   1.0
# 5780                      Dog Days Are Over (Radio Edit)  10621   2.0
# 27314                                     You're The One   9590   3.0
# 19542                                            Secrets   9119   4.0
# 18636                                            Revelry   8988   5.0
# 25070                                               Undo   8836   6.0
# 7530                                           Fireflies   7884   7.0
# 9640                                    Hey_ Soul Sister   7714   8.0
# 25216                                       Use Somebody   7610   9.0
# 9921   Horn Concerto No. 4 in E flat K495: II. Romanc...   7422  10.0

# %% [markdown]
# 基于物品的协同过滤推荐

# %%
triplet_dataset_sub_song_merged = pd.read_csv(filepath_or_buffer='triplet_dataset_sub_song_merged.csv',encoding = "ISO-8859-1")
song_count_df = pd.read_csv(filepath_or_buffer='song_playcount_df.csv')
play_count_df = pd.read_csv(filepath_or_buffer='user_playcount_df.csv')
play_count_subset = play_count_df.head(n=100)
song_count_subset = song_count_df.head(n=100)
user_subset = list(play_count_subset.user)
song_subset = list(song_count_subset.song)
#选取部分数据，用户播放量和歌曲播放量均为前100的数据
triplet_dataset_sub_song_merged_sub = triplet_dataset_sub_song_merged[triplet_dataset_sub_song_merged.song.isin(song_subset)]
triplet_dataset_sub_song_merged_sub = triplet_dataset_sub_song_merged_sub[triplet_dataset_sub_song_merged_sub.user.isin(user_subset)]

# %%
triplet_dataset_sub_song_merged_sub.to_csv(path_or_buf='triplet_dataset_sub_song_merged_sub.csv', index = False)

# %%
#数据大小
triplet_dataset_sub_song_merged_sub = pd.read_csv(filepath_or_buffer='triplet_dataset_sub_song_merged_sub.csv',encoding = "ISO-8859-1")
triplet_dataset_sub_song_merged_sub.shape
# Out:
# (2039, 7)

# %%
#利用Jaccard相似系数进行推荐
import Recommenders as n
triplet_dataset_sub_song_merged_sub = pd.read_csv(filepath_or_buffer='triplet_dataset_sub_song_merged_sub.csv',encoding = "ISO-8859-1")
#train_data, test_data = train_test_split(triplet_dataset_sub_song_merged_sub, test_size = 0.30, random_state=0)
train_data = triplet_dataset_sub_song_merged_sub
is_model = n.item_similarity_recommender_py()
is_model.create(train_data, 'user', 'title')
user_id = list(train_data.user)[8]
is_model.recommend(user_id)
#user_items = is_model.get_user_items(user_id)
# Out:
# No. of unique songs for the user: 17
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :1684
#                                     user_id  \
# 0  283882c3d18ff2ad0e17124002ec02b847d06e9a
# 1  283882c3d18ff2ad0e17124002ec02b847d06e9a
# 2  283882c3d18ff2ad0e17124002ec02b847d06e9a
# 3  283882c3d18ff2ad0e17124002ec02b847d06e9a
# 4  283882c3d18ff2ad0e17124002ec02b847d06e9a
#
#                                                 song     score rank
# 0                                               Undo  0.390851    1
# 1                                  ReprÃÂÃÂ©sente  0.390698    2
# 2                   Pursuit Of Happiness (nightmare)  0.381792    3
# 3  Catch You Baby (Steve Pitron & Max Sanna Radio...  0.380663    4
# 4                                          Alejandro  0.378687    5

# %%
#考虑用户活跃度以及对相似度矩阵归一化后的推荐
import recom as n
triplet_dataset_sub_song_merged_sub = pd.read_csv(filepath_or_buffer='triplet_dataset_sub_song_merged_sub.csv',encoding = "ISO-8859-1")
#train_data, test_data = train_test_split(triplet_dataset_sub_song_merged_sub, test_size = 0.30, random_state=0)
train_data = triplet_dataset_sub_song_merged_sub
is_model = n.item_similarity_recommender_py()
is_model.create(train_data, 'user', 'title')
user_id = list(train_data.user)[8]
is_model.recommend(user_id)
# Out:
# No. of unique songs for the user: 17
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :1684
#                                     user_id  \
# 0  283882c3d18ff2ad0e17124002ec02b847d06e9a
# 1  283882c3d18ff2ad0e17124002ec02b847d06e9a
# 2  283882c3d18ff2ad0e17124002ec02b847d06e9a
# 3  283882c3d18ff2ad0e17124002ec02b847d06e9a
# 4  283882c3d18ff2ad0e17124002ec02b847d06e9a
#
#                                                 song     score rank
# 0                                               Undo  0.480139    1
# 1                                           Tive Sim  0.468004    2
# 2                                  ReprÃÂÃÂ©sente  0.466916    3
# 3                                   Hey_ Soul Sister  0.460323    4
# 4  Catch You Baby (Steve Pitron & Max Sanna Radio...  0.458471    5

# %%
#推荐系统测评
import Recommenders as n
from sklearn.model_selection import KFold
#import n as n
train_data = pd.read_csv(filepath_or_buffer='triplet_dataset_sub_song_merged_sub.csv',encoding = "ISO-8859-1")
is_model = n.item_similarity_recommender_py()
is_model.create(train_data, 'user', 'title')
all_song = is_model.get_all_items_train_data()
pre_list = []
rec_list = []
cov_list = []
#K折交叉验证，这里选择将数据集分成5份，每份轮流作为验证集，其余作为训练集
kf = KFold(n_splits=5,shuffle=True,random_state = 5)
for i, (train_index, test_index) in enumerate(kf.split(train_data)):
    hit = 0
    n_pre = 0
    n_rec = 0
    test = []
    train = []
    rec_all = []
    column = ['user_id', 'song']
    mydf = pd.DataFrame(columns=column)
    df = pd.DataFrame(columns=column)
    #利用Kfold划分出来的只是索引号，根据索引号找到所需数据，分别存入训练集、验证集
    for j in test_index:
        u = list(train_data.user)[j]
        s = list(train_data.song)[j]
        #mydf = pd.DataFrame(columns=column)
       # mm = pd.DataFrame([[u,s]])
        #mydf = mydf.append(mm)
        mydf.loc[len(mydf)] = [u, s]
        if u not in test:
            test.append(u)
    for k in train_index:
        uu = list(train_data.user)[k]
        ss = list(train_data.song)[k]
        df.loc[len(df)] = [uu, ss]
        if uu not in train:
            train.append(uu)

    #print(df,test,train)
    #对训练集中每个用户进行推荐
    for uid in train:
        if uid not in test:
            continue
        else:
            model_train = n.item_similarity_recommender_py()
            model_train.create(df, 'user_id', 'song')
            model_test = n.item_similarity_recommender_py()
            model_test.create(mydf,'user_id', 'song')
            #记录推荐结果
            rec = model_train.recommend(uid)
            #在测试集中找出此推荐用户听过的歌
            listen_items = set(model_test.get_user_items(uid))
            #print(listen_items)
            rec_item = set(rec['song'])
                #print("推荐", rec_item)
                #找出推荐的和用户听过歌的交集
            ht = len(listen_items.intersection(rec_item))
        #推荐到用户听过的歌的总数
        hit = ht + hit
        #总推荐数
        n_pre = n_pre + len(rec_item)
        #用户总共听过的歌
        n_rec = n_rec + len(listen_items)
        #推荐了多少不同的歌
        for item in list(rec.song):
            if item not in rec_all:
                rec_all.append(item)
        # 计算准确率、召回率、覆盖率
    pre_list.append(hit/(1.0*n_pre))
    rec_list.append(hit/(1.0*n_rec))
    cov_list.append(len(rec_all)/len(all_song))
#计算k次的结果取平均
print(pre_list,rec_list,cov_list)
print('准确率:', np.mean(pre_list))
print('召回率：', np.mean(rec_list))
print('覆盖率', np.mean(cov_list))
# Out:
# No. of unique songs for the user: 13
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :1286
# No. of unique songs for the user: 11
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :1089
# No. of unique songs for the user: 11
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :1089
# No. of unique songs for the user: 38
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :3762
# No. of unique songs for the user: 2
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :198
# No. of unique songs for the user: 59
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :5843
# No. of unique songs for the user: 26
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :2570
# No. of unique songs for the user: 39
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :3861
# No. of unique songs for the user: 31
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :3069
# No. of unique songs for the user: 23
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :2275
# No. of unique songs for the user: 1
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :100
# No. of unique songs for the user: 69
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :6831
# No. of unique songs for the user: 1
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :8
# No. of unique songs for the user: 8
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :792
# No. of unique songs for the user: 7
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :690
# No. of unique songs for the user: 6
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :595
# No. of unique songs for the user: 6
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :594
# No. of unique songs for the user: 6
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :594
# No. of unique songs for the user: 45
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :4457
# No. of unique songs for the user: 32
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :3169
# No. of unique songs for the user: 60
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :5943
# No. of unique songs for the user: 15
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :1485
# No. of unique songs for the user: 7
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :693
# No. of unique songs for the user: 43
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :4254
# No. of unique songs for the user: 13
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :1286
# No. of unique songs for the user: 45
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :4456
# No. of unique songs for the user: 9
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :888
# No. of unique songs for the user: 15
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :1484
# No. of unique songs for the user: 2
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :197
# No. of unique songs for the user: 20
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :1981
# No. of unique songs for the user: 5
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :495
# No. of unique songs for the user: 28
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :2770
# No. of unique songs for the user: 64
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :6338
# No. of unique songs for the user: 66
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :6538
# No. of unique songs for the user: 2
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :198
# No. of unique songs for the user: 76
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :7525
# No. of unique songs for the user: 23
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :2279
# No. of unique songs for the user: 25
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :2473
# No. of unique songs for the user: 16
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :1584
# No. of unique songs for the user: 17
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :1682
# No. of unique songs for the user: 3
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :297
# No. of unique songs for the user: 6
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :594
# No. of unique songs for the user: 1
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :99
# No. of unique songs for the user: 26
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :2571
# No. of unique songs for the user: 38
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :3761
# No. of unique songs for the user: 39
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :3860
# No. of unique songs for the user: 19
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :1880
# No. of unique songs for the user: 1
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :99
# No. of unique songs for the user: 13
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :1289
# No. of unique songs for the user: 1
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :99
# No. of unique songs for the user: 3
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :296
# No. of unique songs for the user: 11
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :1089
# No. of unique songs for the user: 4
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :397
# No. of unique songs for the user: 3
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :295
# No. of unique songs for the user: 16
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :1584
# No. of unique songs for the user: 7
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :693
# No. of unique songs for the user: 3
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :297
# No. of unique songs for the user: 10
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :991
# No. of unique songs for the user: 6
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :594
# No. of unique songs for the user: 52
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :5146
# No. of unique songs for the user: 43
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :4257
# No. of unique songs for the user: 46
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :4558
# No. of unique songs for the user: 24
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :2377
# No. of unique songs for the user: 8
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :792
# No. of unique songs for the user: 28
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :2771
# No. of unique songs for the user: 77
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :7624
# No. of unique songs for the user: 18
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :1779
# No. of unique songs for the user: 2
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :198
# No. of unique songs for the user: 21
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :2077
# No. of unique songs for the user: 9
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :888
# No. of unique songs for the user: 17
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :1683
# No. of unique songs for the user: 4
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :396
# No. of unique songs for the user: 2
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :198
# No. of unique songs for the user: 4
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :394
# No. of unique songs for the user: 11
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :1086
# No. of unique songs for the user: 10
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :991
# No. of unique songs for the user: 7
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :695
# No. of unique songs for the user: 35
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :3463
# No. of unique songs for the user: 3
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :297
# No. of unique songs for the user: 6
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :596
# No. of unique songs for the user: 60
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :5942
# No. of unique songs for the user: 23
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :2277
# No. of unique songs for the user: 41
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :4060
# No. of unique songs for the user: 25
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :2472
# No. of unique songs for the user: 23
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :2273
# No. of unique songs for the user: 14
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :1387
# No. of unique songs for the user: 73
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :7231
# No. of unique songs for the user: 14
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :1386
# No. of unique songs for the user: 5
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :494
# No. of unique songs for the user: 6
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :594
# No. of unique songs for the user: 8
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :792
# No. of unique songs for the user: 7
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :693
# No. of unique songs for the user: 44
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :4357
# No. of unique songs for the user: 31
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :3068
# No. of unique songs for the user: 59
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :5842
# No. of unique songs for the user: 13
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :1287
# No. of unique songs for the user: 37
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :3661
# No. of unique songs for the user: 13
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :1287
# No. of unique songs for the user: 41
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :4064
# No. of unique songs for the user: 10
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :989
# No. of unique songs for the user: 16
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :1581
# No. of unique songs for the user: 22
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :2178
# No. of unique songs for the user: 29
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :2871
# No. of unique songs for the user: 65
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :6437
# No. of unique songs for the user: 68
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :6735
# No. of unique songs for the user: 2
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :198
# No. of unique songs for the user: 85
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :8416
# No. of unique songs for the user: 18
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :1783
# No. of unique songs for the user: 25
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :2473
# No. of unique songs for the user: 19
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :1883
# No. of unique songs for the user: 3
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :297
# No. of unique songs for the user: 17
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :1684
# No. of unique songs for the user: 3
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :298
# No. of unique songs for the user: 5
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :495
# No. of unique songs for the user: 22
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :2179
# No. of unique songs for the user: 40
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :3962
# No. of unique songs for the user: 42
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :4160
# No. of unique songs for the user: 18
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :1783
# No. of unique songs for the user: 11
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :1090
# No. of unique songs for the user: 12
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :1188
# No. of unique songs for the user: 5
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :496
# No. of unique songs for the user: 3
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :297
# No. of unique songs for the user: 19
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :1879
# No. of unique songs for the user: 7
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :693
# No. of unique songs for the user: 2
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :108
# No. of unique songs for the user: 3
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :297
# No. of unique songs for the user: 50
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :4949
# No. of unique songs for the user: 49
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :4849
# No. of unique songs for the user: 6
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :594
# No. of unique songs for the user: 45
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :4455
# No. of unique songs for the user: 17
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :1684
# No. of unique songs for the user: 5
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :495
# No. of unique songs for the user: 36
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :3564
# No. of unique songs for the user: 75
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :7427
# No. of unique songs for the user: 18
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :1783
# No. of unique songs for the user: 2
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :198
# No. of unique songs for the user: 20
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :1979
# No. of unique songs for the user: 12
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :1190
# No. of unique songs for the user: 1
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :99
# No. of unique songs for the user: 10
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :990
# No. of unique songs for the user: 13
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :1287
# No. of unique songs for the user: 4
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :396
# No. of unique songs for the user: 2
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :198
# No. of unique songs for the user: 16
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :1582
# No. of unique songs for the user: 10
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :988
# No. of unique songs for the user: 11
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :1087
# No. of unique songs for the user: 38
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :3756
# No. of unique songs for the user: 3
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :297
# No. of unique songs for the user: 6
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :593
# No. of unique songs for the user: 62
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :6129
# No. of unique songs for the user: 29
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :2857
# No. of unique songs for the user: 42
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :4155
# No. of unique songs for the user: 33
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :3254
# No. of unique songs for the user: 21
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :2078
# No. of unique songs for the user: 3
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :297
# No. of unique songs for the user: 11
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :1085
# No. of unique songs for the user: 75
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :7417
# No. of unique songs for the user: 11
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :1081
# No. of unique songs for the user: 7
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :691
# No. of unique songs for the user: 5
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :494
# No. of unique songs for the user: 9
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :887
# No. of unique songs for the user: 7
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :692
# No. of unique songs for the user: 40
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :3955
# No. of unique songs for the user: 26
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :2569
# No. of unique songs for the user: 61
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :6032
# No. of unique songs for the user: 14
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :1385
# No. of unique songs for the user: 7
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :691
# No. of unique songs for the user: 37
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :3649
# No. of unique songs for the user: 12
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :1188
# No. of unique songs for the user: 45
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :4448
# No. of unique songs for the user: 7
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :691
# No. of unique songs for the user: 16
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :1581
# No. of unique songs for the user: 24
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :2368
# No. of unique songs for the user: 6
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :595
# No. of unique songs for the user: 26
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :2566
# No. of unique songs for the user: 64
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :6327
# No. of unique songs for the user: 70
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :6924
# No. of unique songs for the user: 80
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :7910
# No. of unique songs for the user: 19
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :1881
# No. of unique songs for the user: 24
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :2369
# No. of unique songs for the user: 15
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :1483
# No. of unique songs for the user: 3
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :297
# No. of unique songs for the user: 2
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :198
# No. of unique songs for the user: 18
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :1778
# No. of unique songs for the user: 26
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :2568
# No. of unique songs for the user: 41
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :4053
# No. of unique songs for the user: 48
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :4746
# No. of unique songs for the user: 16
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :1582
# No. of unique songs for the user: 16
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :1584
# No. of unique songs for the user: 2
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :197
# No. of unique songs for the user: 9
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :888
# No. of unique songs for the user: 5
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :496
# No. of unique songs for the user: 3
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :296
# No. of unique songs for the user: 13
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :1280
# No. of unique songs for the user: 5
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :496
# No. of unique songs for the user: 2
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :106
# No. of unique songs for the user: 2
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :191
# No. of unique songs for the user: 7
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :686
# No. of unique songs for the user: 49
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :4838
# No. of unique songs for the user: 43
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :4252
# No. of unique songs for the user: 6
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :595
# No. of unique songs for the user: 41
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :4057
# No. of unique songs for the user: 20
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :1980
# No. of unique songs for the user: 8
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :793
# No. of unique songs for the user: 31
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :3067
# No. of unique songs for the user: 81
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :8009
# No. of unique songs for the user: 17
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :1683
# No. of unique songs for the user: 26
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :2573
# No. of unique songs for the user: 10
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :988
# No. of unique songs for the user: 2
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :198
# No. of unique songs for the user: 10
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :989
# No. of unique songs for the user: 12
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :1189
# No. of unique songs for the user: 4
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :305
# No. of unique songs for the user: 3
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :297
# No. of unique songs for the user: 5
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :494
# No. of unique songs for the user: 13
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :1281
# No. of unique songs for the user: 10
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :990
# No. of unique songs for the user: 10
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :988
# No. of unique songs for the user: 32
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :3161
# No. of unique songs for the user: 4
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :396
# No. of unique songs for the user: 58
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :5727
# No. of unique songs for the user: 28
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :2763
# No. of unique songs for the user: 38
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :3752
# No. of unique songs for the user: 27
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :2668
# No. of unique songs for the user: 23
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :2270
# No. of unique songs for the user: 2
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :196
# No. of unique songs for the user: 14
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :1379
# No. of unique songs for the user: 71
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :7014
# No. of unique songs for the user: 1
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :97
# No. of unique songs for the user: 13
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :1285
# No. of unique songs for the user: 5
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :491
# No. of unique songs for the user: 5
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :494
# No. of unique songs for the user: 8
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :787
# No. of unique songs for the user: 5
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :493
# No. of unique songs for the user: 47
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :4645
# No. of unique songs for the user: 34
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :3358
# No. of unique songs for the user: 60
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :5928
# No. of unique songs for the user: 16
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :1584
# No. of unique songs for the user: 8
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :790
# No. of unique songs for the user: 39
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :3843
# No. of unique songs for the user: 14
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :1386
# No. of unique songs for the user: 46
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :4540
# No. of unique songs for the user: 1
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :99
# No. of unique songs for the user: 9
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :885
# No. of unique songs for the user: 14
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :1380
# No. of unique songs for the user: 26
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :2570
# No. of unique songs for the user: 5
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :494
# No. of unique songs for the user: 25
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :2465
# No. of unique songs for the user: 63
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :6227
# No. of unique songs for the user: 67
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :6618
# No. of unique songs for the user: 2
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :198
# No. of unique songs for the user: 77
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :7604
# No. of unique songs for the user: 19
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :1879
# No. of unique songs for the user: 18
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :1773
# No. of unique songs for the user: 17
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :1676
# No. of unique songs for the user: 2
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :198
# No. of unique songs for the user: 3
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :297
# No. of unique songs for the user: 20
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :1972
# No. of unique songs for the user: 4
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :395
# No. of unique songs for the user: 5
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :493
# No. of unique songs for the user: 2
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :198
# No. of unique songs for the user: 27
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :2665
# No. of unique songs for the user: 40
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :3947
# No. of unique songs for the user: 47
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :4641
# No. of unique songs for the user: 19
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :1874
# No. of unique songs for the user: 15
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :1485
# No. of unique songs for the user: 5
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :493
# No. of unique songs for the user: 9
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :889
# No. of unique songs for the user: 3
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :297
# No. of unique songs for the user: 14
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :1379
# No. of unique songs for the user: 6
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :594
# No. of unique songs for the user: 2
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :198
# No. of unique songs for the user: 9
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :888
# No. of unique songs for the user: 4
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :395
# No. of unique songs for the user: 50
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :4938
# No. of unique songs for the user: 42
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :4152
# No. of unique songs for the user: 7
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :690
# No. of unique songs for the user: 44
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :4342
# No. of unique songs for the user: 25
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :2463
# No. of unique songs for the user: 32
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :3162
# No. of unique songs for the user: 80
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :7902
# No. of unique songs for the user: 20
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :1975
# No. of unique songs for the user: 2
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :198
# No. of unique songs for the user: 23
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :2275
# No. of unique songs for the user: 14
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :1382
# No. of unique songs for the user: 10
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :986
# No. of unique songs for the user: 14
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :1385
# No. of unique songs for the user: 3
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :295
# No. of unique songs for the user: 4
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :394
# No. of unique songs for the user: 3
# no. of unique songs in the training set: 99
# Non zero values in cooccurence_matrix :297
# No. of unique songs for the user: 15
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :1480
# No. of unique songs for the user: 7
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :691
# No. of unique songs for the user: 9
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :892
# No. of unique songs for the user: 33
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :3263
# No. of unique songs for the user: 5
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :496
# No. of unique songs for the user: 57
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :5635
# No. of unique songs for the user: 22
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :2166
# No. of unique songs for the user: 36
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :3553
# No. of unique songs for the user: 24
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :2376
# No. of unique songs for the user: 22
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :2171
# No. of unique songs for the user: 2
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :198
# No. of unique songs for the user: 3
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :296
# No. of unique songs for the user: 15
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :1484
# No. of unique songs for the user: 68
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :6718
# No. of unique songs for the user: 14
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :1384
# No. of unique songs for the user: 6
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :595
# No. of unique songs for the user: 9
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :891
# No. of unique songs for the user: 7
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :683
# No. of unique songs for the user: 48
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :4745
# No. of unique songs for the user: 29
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :2867
# No. of unique songs for the user: 68
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :6724
# No. of unique songs for the user: 18
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :1777
# No. of unique songs for the user: 5
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :493
# No. of unique songs for the user: 40
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :3953
# No. of unique songs for the user: 12
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :1187
# No. of unique songs for the user: 47
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :4650
# No. of unique songs for the user: 1
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :97
# No. of unique songs for the user: 9
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :886
# No. of unique songs for the user: 19
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :1878
# No. of unique songs for the user: 1
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :99
# No. of unique songs for the user: 24
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :2377
# No. of unique songs for the user: 5
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :495
# No. of unique songs for the user: 20
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :1973
# No. of unique songs for the user: 68
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :6720
# No. of unique songs for the user: 69
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :6823
# No. of unique songs for the user: 74
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :7316
# No. of unique songs for the user: 21
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :2078
# No. of unique songs for the user: 24
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :2373
# No. of unique songs for the user: 13
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :1282
# No. of unique songs for the user: 3
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :297
# No. of unique songs for the user: 16
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :1584
# No. of unique songs for the user: 5
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :493
# No. of unique songs for the user: 27
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :2660
# No. of unique songs for the user: 49
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :4837
# No. of unique songs for the user: 44
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :4352
# No. of unique songs for the user: 16
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :1582
# No. of unique songs for the user: 1
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :99
# No. of unique songs for the user: 13
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :1285
# No. of unique songs for the user: 4
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :394
# No. of unique songs for the user: 11
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :1086
# No. of unique songs for the user: 4
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :396
# No. of unique songs for the user: 18
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :1778
# No. of unique songs for the user: 7
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :693
# No. of unique songs for the user: 7
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :692
# No. of unique songs for the user: 4
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :396
# No. of unique songs for the user: 55
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :5431
# No. of unique songs for the user: 43
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :4250
# No. of unique songs for the user: 5
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :496
# No. of unique songs for the user: 36
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :3559
# No. of unique songs for the user: 22
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :2175
# No. of unique songs for the user: 6
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :595
# No. of unique songs for the user: 33
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :3263
# No. of unique songs for the user: 79
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :7811
# No. of unique songs for the user: 19
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :1877
# No. of unique songs for the user: 22
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :2166
# No. of unique songs for the user: 15
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :1484
# No. of unique songs for the user: 9
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :877
# No. of unique songs for the user: 16
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :1584
# No. of unique songs for the user: 5
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :408
# No. of unique songs for the user: 2
# no. of unique songs in the training set: 100
# Non zero values in cooccurence_matrix :197
# [0.1918918918918919, 0.18840579710144928, 0.16944444444444445, 0.192, 0.19428571428571428] [0.17530864197530865, 0.15931372549019607, 0.15099009900990099, 0.17647058823529413, 0.16748768472906403] [0.63, 0.5, 0.5, 0.56, 0.52]
# 准确率: 0.18720556954469997
# 召回率： 0.16591414788795278
# 覆盖率 0.542
